# %% [markdown]
# </h2>What was the most common age on the ship?
#
#
#
#
# I will do a census study because i have the knowledge of passengers' and crews' ages.

# %%
import pandas as pd
t = pd.read_csv('titanic.csv')

print(t[['PassengerId', 'Age']])
# Out:
#      PassengerId   Age
# 0              1  22.0
# 1              2  38.0
# 2              3  26.0
# 3              4  35.0
# 4              5  35.0
# ..           ...   ...
# 886          887  27.0
# 887          888  19.0
# 888          889   NaN
# 889          890  26.0
# 890          891  32.0
#
# [891 rows x 2 columns]
